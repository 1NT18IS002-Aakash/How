# %%
import pandas as pd
import statistics as st
import math
import scipy.stats
import matplotlib.pyplot as plt

data=pd.read_csv('data.csv')
print(data)

sx=st.stdev(data['x'])
print("Standard Derivation of x",sx)

sy=st.stdev(data['y'])
print("Standard Derivation of y",sy)

r=scipy.stats.pearsonr(data['x'],data['y'])[0]
print("Correlation coefficient ",r)

#slope
slope=r*sy/sx
print("Slope",slope)

mx=st.mean(data['x'])
my=st.mean(data['y'])
print(mx,my)

c=my-slope*mx
print("c",c)

y_pred=slope*data['x']+c
print(y_pred)
#for i in range(len(data)):
#    y1.append(slope*data['x'][i]+c)
#print(y1)

#plotting graph
plt.scatter(data['x'],data['y'])
plt.plot(data['x'],y_pred,color="red")

#cost
cost=abs(data['y']-y_pred)
print("Cost is ",cost.values)

#sum squared error
sse=sum(cost**2)
print("Sum of Square error ",sse)

#sum squares of total
sst=sum((data['y']-st.mean(data['y']))**2)
print("Sum of Squares total ",sst)

#sum squares of regression
ssr=sum((y_pred-st.mean(y_pred))**2)
print("Sum of Squares regression ",ssr)

#r square
rsq=ssr/sst
print("R square",rsq)
# Out:
#      x    y
# 0  5.9  6.2
# 1  4.6  2.9
# 2  6.2  2.8
# 3  4.7  3.2
# 4  5.0  3.0
# 5  5.5  4.2
# 6  4.9  3.0
# 7  6.7  3.1
# 8  5.1  3.1
# 9  6.0  3.0
# Standard Derivation of x 0.7105553383719589
# Standard Derivation of y 1.041633332799983
# Correlation coefficient  0.1996624315608937
# Slope 0.29269366197183105
# 5.46 3.45
# c 1.8518926056338025
# 0    3.578785
# 1    3.198283
# 2    3.666593
# 3    3.227553
# 4    3.315361
# 5    3.461708
# 6    3.286092
# 7    3.812940
# 8    3.344630
# 9    3.608055
# Name: x, dtype: float64
# Cost is  [2.62121479 0.29828345 0.86659331 0.02755282 0.31536092 0.73829225
#  0.28609155 0.71294014 0.24463028 0.60805458]
# Sum of Square error  9.375717429577465
# Sum of Squares total  9.765000000000004
# Sum of Squares regression  0.3892825704225357
# R square 0.03986508657680856

# %%
d = pd.read_csv('data.csv')
d
# Out:
#      x    y
# 0  5.9  6.2
# 1  4.6  2.9
# 2  6.2  2.8
# 3  4.7  3.2
# 4  5.0  3.0
# 5  5.5  4.2
# 6  4.9  3.0
# 7  6.7  3.1
# 8  5.1  3.1
# 9  6.0  3.0
